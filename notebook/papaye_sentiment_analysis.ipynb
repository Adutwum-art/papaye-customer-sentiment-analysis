# %%
import pandas as pd

df = pd.read_excel(
    r"C:\Users\Richard\Desktop\PYTHON JOURNEY\Python\Sentimental\Combined_Haatso_Tema_Analysis_Dataset.xlsx"
)

print(df.shape)
# Out:
# (134, 9)

# %%
from nltk.sentiment import SentimentIntensityAnalyzer

sia = SentimentIntensityAnalyzer()

df['compound_score'] = df['Clean_Review_Text'].astype(str).apply(
    lambda x: sia.polarity_scores(x)['compound']
)

def sentiment_label(score):
    if score >= 0.05:
        return 'Positive'
    elif score <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

df['Predicted_Sentiment'] = df['compound_score'].apply(sentiment_label)

# %%
df['Predicted_Sentiment'].value_counts()
# Out:
# Predicted_Sentiment
# Positive    82
# Negative    31
# Neutral     21
# Name: count, dtype: int64

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = " ".join(df['Clean_Review_Text'].astype(str))

wordcloud = WordCloud(
    width=1200,
    height=600,
    background_color='white'
).generate(text)

plt.figure(figsize=(12,6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Customer Review Word Cloud')
plt.savefig('wordcloud.png', bbox_inches='tight')
plt.show()

# %%
sentiment_counts = df['Predicted_Sentiment'].value_counts()

plt.figure(figsize=(7,5))
sentiment_counts.plot(kind='bar')

plt.title('Overall Sentiment Distribution')
plt.xlabel('Sentiment')
plt.ylabel('Number of Reviews')

plt.tight_layout()
plt.savefig('sentiment_distribution.png')
plt.show()

# %%
branch_ratings = df.groupby('Branch')['Overall_Rating'].mean()

plt.figure(figsize=(6,4))
branch_ratings.plot(kind='bar')

plt.title('Average Overall Rating by Branch')
plt.xlabel('Branch')
plt.ylabel('Average Rating')

plt.xticks(rotation=0)

plt.tight_layout()
plt.savefig('branch_comparison.png')
plt.show()

# %%
df.to_excel(
    'Papaye_Sentiment_Analysis_Final.xlsx',
    index=False
)

# %%
summary = df.groupby('Branch')[[
    'Overall_Rating',
    'Food_Rating',
    'Service_Rating',
    'Atmosphere_Rating'
]].mean().round(2)

summary.to_excel('branch_summary.xlsx')
summary
# Out:
#         Overall_Rating  Food_Rating  Service_Rating  Atmosphere_Rating
# Branch
# Haatso            3.81         3.68            3.55               3.85
# Tema              3.42         3.46            3.21               3.52

# %%
import pandas as pd

df = pd.read_excel(
    r"C:\Users\Richard\Desktop\PYTHON JOURNEY\Python\Sentimental\Combined_Haatso_Tema_Analysis_Dataset.xlsx"
)

from nltk.sentiment import SentimentIntensityAnalyzer

sia = SentimentIntensityAnalyzer()

df['compound_score'] = df['Clean_Review_Text'].astype(str).apply(
    lambda x: sia.polarity_scores(x)['compound']
)

def sentiment_label(score):
    if score >= 0.05:
        return 'Positive'
    elif score <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

df['Predicted_Sentiment'] = df['compound_score'].apply(sentiment_label)

# %%
df['Predicted_Sentiment'].value_counts()
# Out:
# Predicted_Sentiment
# Positive    82
# Negative    31
# Neutral     21
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

sentiment_counts = df['Predicted_Sentiment'].value_counts()

plt.figure(figsize=(7,5))
sentiment_counts.plot(kind='bar')

plt.title('Overall Sentiment Distribution')
plt.xlabel('Sentiment')
plt.ylabel('Number of Reviews')

plt.show()

# %%
branch_ratings = df.groupby('Branch')['Overall_Rating'].mean()

plt.figure(figsize=(6,4))
branch_ratings.plot(kind='bar')

plt.title('Average Overall Rating by Branch')
plt.xlabel('Branch')
plt.ylabel('Average Rating')

plt.xticks(rotation=0)

plt.show()

# %%
import matplotlib.pyplot as plt

sentiment_counts = df['Predicted_Sentiment'].value_counts()

plt.figure(figsize=(7,5))
sentiment_counts.plot(kind='bar')

plt.title('Overall Sentiment Distribution')
plt.xlabel('Sentiment')
plt.ylabel('Number of Reviews')

plt.show()
plt.tight_layout()
plt.savefig('sentiment_distribution.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
branch_ratings = df.groupby('Branch')['Overall_Rating'].mean()

plt.figure(figsize=(6,4))
branch_ratings.plot(kind='bar')

plt.title('Average Overall Rating by Branch')
plt.xlabel('Branch')
plt.ylabel('Average Rating')

plt.xticks(rotation=0)

plt.show()
plt.tight_layout()
plt.savefig('branch_comparison.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Richard'

# %%
import pandas as pd

df = pd.read_excel(
    r"C:\Users\Richard\Desktop\PYTHON JOURNEY\Python\Sentimental\Combined_Haatso_Tema_Analysis_Dataset.xlsx"
)

from nltk.sentiment import SentimentIntensityAnalyzer

sia = SentimentIntensityAnalyzer()

df['compound_score'] = df['Clean_Review_Text'].astype(str).apply(
    lambda x: sia.polarity_scores(x)['compound']
)

def sentiment_label(score):
    if score >= 0.05:
        return 'Positive'
    elif score <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

df['Predicted_Sentiment'] = df['compound_score'].apply(sentiment_label)
df['Predicted_Sentiment'].value_counts()
# Out:
# Predicted_Sentiment
# Positive    82
# Negative    31
# Neutral     21
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

sentiment_counts = df['Predicted_Sentiment'].value_counts()

plt.figure(figsize=(7,5))
sentiment_counts.plot(kind='bar')

plt.title('Overall Sentiment Distribution')
plt.xlabel('Sentiment')
plt.ylabel('Number of Reviews')

plt.show()
plt.tight_layout()
plt.savefig('sentiment_distribution.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

sentiment_counts = df['Predicted_Sentiment'].value_counts()

plt.figure(figsize=(7,5))
sentiment_counts.plot(kind='bar')

plt.title('Overall Sentiment Distribution')
plt.xlabel('Sentiment')
plt.ylabel('Number of Reviews')

plt.tight_layout()

plt.savefig(
    'sentiment_distribution.png',
    dpi=300,
    bbox_inches='tight'
)

plt.show()

# %%
branch_ratings = df.groupby('Branch')['Overall_Rating'].mean()

plt.figure(figsize=(6,4))
branch_ratings.plot(kind='bar')

plt.title('Average Overall Rating by Branch')
plt.xlabel('Branch')
plt.ylabel('Average Rating')

plt.xticks(rotation=0)

plt.show()
plt.tight_layout()
plt.savefig('branch_comparison.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

branch_ratings = df.groupby('Branch')['Overall_Rating'].mean()

plt.figure(figsize=(6,4))
branch_ratings.plot(kind='bar')

plt.title('Average Overall Rating by Branch')
plt.xlabel('Branch')
plt.ylabel('Average Rating')

plt.xticks(rotation=0)

plt.tight_layout()

plt.savefig(
    'branch_comparison.png',
    dpi=300,
    bbox_inches='tight'
)

plt.show()

# %%
plt.savefig(
    r"C:\Users\Richard\Desktop\PYTHON JOURNEY\Python\Sentimental\sentiment_distribution.png",
    dpi=300,
    bbox_inches='tight'
)

# %%
sentiment_pct = (
    df['Predicted_Sentiment']
    .value_counts(normalize=True)
    .mul(100)
    .round(2)
)

print(sentiment_pct)
import matplotlib.pyplot as plt

sentiment_pct.plot(kind='bar')

plt.title('Overall Sentiment Distribution (%)')
plt.xlabel('Sentiment')
plt.ylabel('Percentage of Reviews')

plt.tight_layout()

plt.savefig(
    'sentiment_distribution_percent.png',
    dpi=300,
    bbox_inches='tight'
)

plt.show()

# %%
import matplotlib.pyplot as plt

sentiment_pct = (
    df['Predicted_Sentiment']
    .value_counts(normalize=True)
    .mul(100)
    .round(2)
)

plt.figure(figsize=(7,5))

sentiment_pct.plot(kind='bar')

plt.title('Overall Sentiment Distribution (%)')
plt.xlabel('Sentiment')
plt.ylabel('Percentage of Reviews')

plt.tight_layout()

plt.savefig(
    r"C:\Users\Richard\Desktop\PYTHON JOURNEY\Python\Sentimental\sentiment_distribution_percent.png",
    dpi=300,
    bbox_inches='tight'
)

plt.show()

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Richard

# %%
import os

for file in os.listdir():
    if file.endswith(".ipynb"):
        print(file)
# Out:
# Combined_Haatso_Tema_Analysis_Dataset.xlsx.ipynb
